# %% [markdown]
# # Chapter 1. The Way of the Program

# %% [markdown]
# > You can think of programming as the process of breaking a large, complex task into smaller subtasks until the subtasks are simple enough to be performed with one of these bacis instructions:

# %% [markdown]
# > **Input**: Get data from the keyboard, a file, the network, or some other device.
#
# > **Output**: Display data on the screen, save it in a file, send it over the network, etc.
#
# > **Math**: Perform basic mathematical operations like addition and multiplication.
#
# > **Conditional execution**: Check for certain conditions and run the appropriate code.
#
# > **Repetition**: Perform some action repeatedly, usually with some variation.

# %% [markdown]
# ## Exercise 1_1

# %%
ptin('hhelo')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-913078ded7ae> in <module>
# ----> 1 ptin('hhelo')
#
# NameError: name 'ptin' is not defined

# %%
print(hello)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-1cd80308eb4c> in <module>
# ----> 1 print(hello)
#
# NameError: name 'hello' is not defined

# %%
print('hell'
# Out:
#   File "<ipython-input-6-250151d72fec>", line 1
#     print('hell'
#                 ^
# SyntaxError: unexpected EOF while parsing

# %%
print('hello)
# Out:
#   File "<ipython-input-7-126035ba983d>", line 1
#     print('hello)
#                  ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# *EOF*: end of file
#
# *EOL*: end of life

# %%
2 ++ 2
# Out:
# 4

# %%
02
# Out:
#   File "<ipython-input-15-0908cbeb2fbd>", line 1
#     02
#      ^
# SyntaxError: invalid token

# %%
# two values without operator between them
3  6
# Out:
#   File "<ipython-input-17-2560f3ea0ce0>", line 2
#     3  6
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Exercise 1_2

# %% [markdown]
# ### Minutes to seconds

# %%
# How many seconds are there in 42 minutes 42 seconds?

minutes = int(input('Minutes: '))
seconds = int(input('Seconds: '))

print(f'How many seconds are there in {minutes} minutes {seconds} seconds?')
minutes_to_seconds = int(minutes * 60 + seconds)
print('The result is {} seconds.'.format(minutes_to_seconds))
# Out:
# Minutes:  42
# Seconds:  42
# How many seconds are there in 42 minutes 42 seconds?
# The result is 2562 seconds.

# %%
run ex1_2_1.py
# Out:
# Minutes:  42
# Seconds:  42
# How many seconds are there in 42 minutes 42 seconds?
# The result is 2562 seconds.

# %% [markdown]
# ### Seconds to minutes

# %%
# How many mimutes and seconds are there in 500 seconds?

seconds_to_minutes = int(input('Seconds: '))

print(f'How many minutes and seconds are there in {seconds_to_minutes} seconds?')
minutes = seconds_to_minutes // 60
seconds = seconds_to_minutes % 60
print(f'The result is {minutes} minutes and {seconds} seconds.')
# Out:
# Seconds:  500
# How many minutes and seconds are there in 500 seconds?
# The result is 8 minutes and 20 seconds.

# %%
run ex1_2_2.py
# Out:
# Seconds:  1000
# How many minutes and seconds are there in 1000 seconds?
# The result is 16 minutes and 40 seconds.

# %% [markdown]
# ### Kilometers to miles

# %%
# How many miles are there in 10 kilometers?

kilometers = int(input('Kilometers: '))

print(f'How many miles in {kilometers} kilometers?')
kilometers_per_mile = 1.61
kilometers_to_miles = round(kilometers / kilometers_per_mile, 2)
print('The result is {} miles.'.format(kilometers_to_miles))
# Out:
# Kilometers:  10
# How many miles in 10 kilometers?
# The result is 6.21 miles.

# %%
round??
# Out:
# Docstring:
# round(number[, ndigits]) -> number
#
# Round a number to a given precision in decimal digits (default 0 digits).
# This returns an int when called with one argument, otherwise the
# same type as the number. ndigits may be negative.
# Type:      builtin_function_or_method

# %%
round(3.14)
# Out:
# 3

# %%
round(3.1415, 0)
# Out:
# 3.0

# %% [markdown]
# 注意，可选参数没有或置0的区别

# %%
round(3.1415, 3)
# Out:
# 3.142

# %%
round(3.1415, 6)
# Out:
# 3.1415

# %%
round(100.345, -2)
# Out:
# 100.0

# %%
round(100.345, -1)
# Out:
# 100.0

# %%
round(100.345, -4)
# Out:
# 0.0

# %%
run ex1_2_3.py
# Out:
# Kilometers:  10
# How many miles in 10 kilometers?
# The result is 6.21 miles.

# %% [markdown]
# ### Average pace and average speed

# %%
''' If you run a 10 kilometers race in 42 minutes and 42 seconds, what is your average pace(time per mile 
in minutes and seconds)? What is your average speed in miles per hour?'''

kilometer_race = int(input('Kilometer race: '))
minutes = int(input('Minutes: '))
seconds = int(input('Seconds: '))

print('What is your average pace?')

# seconds per mile
average_pace = round((minutes * 68 + seconds) / (kilometer_race / 1.61), 2)
print('The average pace is {} seconds per mile.'.format(average_pace))

print('What is your average speed?')

# miles per second
average_speed = round((kilometer_race / 1.61) / (minutes * 60 + seconds), 4)
print('The average speed is {} miles per second.'.format(average_speed))
# Out:
# Kilometer race:  10
# Minutes:  42
# Seconds:  42
# What is your average pace?
# The average pace is 466.58 seconds per mile.
# What is your average speed?
# The average speed is 0.0024 miles per second.

# %%
run ex1_2_4.py
# Out:
# Kilometer race:  10
# Minutes:  42
# Seconds:  42
# What is your average pace?
# The average pace is 466.58 seconds per mile.
# What is your average speed?
# The average speed is 0.0024 miles per second.

# %% [markdown]
# # Chapter 2. Variables, Expressions and Statements

# %% [markdown]
# ## The expression 、statement and argument

# %% [markdown]
# The interpreter uses keywords to recognize the structure of the program.
#
# It evaluates or finds the value of the expression. The expression can be looked as a value.
#
# It executes or does whatever the statement says. In general, statements don't have values.

# %% [markdown]
# *argument*是一个value，因此可以是*expression*，*parameter*相当于一个变量名。

# %% [markdown]
# ## Three kinds of errors

# %% [markdown]
# + **Syntax error**
#
#     Refers to the structure of a program and the rules about the structure.
#
# + **Runtime error**
#
#     Refers to something exceptional has happened, also called **exceptions**.
#
# + **Semantic error**
#
#     Related to meaning, without error messages.

# %% [markdown]
# ## Exercise 2_1

# %%
42 = n
# Out:
#   File "<ipython-input-38-f0c37ed646fc>", line 1
#     42 = n
#           ^
# SyntaxError: can't assign to literal

# %%
x = y = 1
print(x)
print(y)
# Out:
# 1
# 1

# %%
x = 3.
print(x)
# Out:
# 3.0

# %%
print(x).
# Out:
#   File "<ipython-input-43-d60a3cc78008>", line 1
#     print(x).
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# 注意，*SyntaxError*都是与结构相关的

# %%
x = 3
y = 4

print(x * y)
print(xy)
# Out:
# 12
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-0ba8a2f4f8eb> in <module>
#       3
#       4 print(x * y)
# ----> 5 print(xy)
#
# NameError: name 'xy' is not defined

# %% [markdown]
# ## Exercise 2_2

# %% [markdown]
# ### Volume of sphere

# %%
# What is the volume of a sphere with radius 5?
from math import pi

radius = 5
volume = 4 / 3 * pi * (radius ** 3)

print('The volume is {}'.format(round(volume,2)))
# Out:
# The volume is 523.6

# %%
run ex2_2_1.py
# Out:
# The volume is 523.6

# %% [markdown]
# ### Wholesale cost

# %%
# The total wholesale cost

cover_price = 24.95
discount = 0.4 
basic_shipping_fee = 3
additional_shipping_fee = 0.75
copies = 60

total_cost = (cover_price * discount * copies) + (basic_shipping_fee + (copies - 1) * additional_shipping_fee)

print('The total wholesale cost is {}'.format(round(total_cost, 2)))
# Out:
# The total wholesale cost is 646.05

# %%
run ex2_2_2.py
# Out:
# The total wholesale cost is 646.05

# %% [markdown]
# ### Breakfast time

# %%
# Breakfast time

# minutes per mile
easy_pace = 8 + 15 / 60
tempo_pace = 7 + 12 / 60

# miles
first_distance = 1
second_distance = 3
third_distance = 1

# minutes
first_time = first_distance * easy_pace
second_time = second_distance * tempo_pace
third_time = third_distance * easy_pace
total_time = first_time + second_time + third_time

hour = (6 * 60 + 52 + total_time) // 60
minute = (6 * 60 + 52 + total_time) % 60
print('The breakfast time is {}:{}.'.format(int(hour), int(minute)))
# Out:
# The breakfast time is 7:30.

# %%
run ex2_2_3.py
# Out:
# The breakfast time is 7:30.

# %% [markdown]
# # Chapter 3. Functions

# %% [markdown]
# ## Object and its use

# %% [markdown]
# Python中的新对象，一般采用type()函数查看类型，采用dir()函数查看属性和方法，针对对象本身或其属性、方法，通过?或??、help()函数来查阅具体信息。

# %% [markdown]
# A *module* is a file that contains a collection of related functions. A *module* should be imported by the `import` statement, then a *module object* is created.

# %% [markdown]
# The *module object* contains the functions and variables defined in the module.

# %%
import math

# %%
math
# Out:
# <module 'math' (built-in)>

# %%
type(math)
# Out:
# module

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'pi',
#  'pow',
#  'radians',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc']

# %%
math?
# Out:
# Type:        module
# String form: <module 'math' (built-in)>
# Docstring:
# This module is always available.  It provides access to the
# mathematical functions defined by the C standard.

# %%
math??
# Out:
# Type:        module
# String form: <module 'math' (built-in)>
# Docstring:
# This module is always available.  It provides access to the
# mathematical functions defined by the C standard.

# %%
help(math)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module is always available.  It provides access to the
#     mathematical functions defined by the C standard.
#
# FUNCTIONS
#     acos(...)
#         acos(x)
#
#         Return the arc cosine (measured in radians) of x.
#
#     acosh(...)
#         acosh(x)
#
#         Return the inverse hyperbolic cosine of x.
#
#     asin(...)
#         asin(x)
#
#         Return the arc sine (measured in radians) of x.
#
#     asinh(...)
#         asinh(x)
#
#         Return the inverse hyperbolic sine of x.
#
#     atan(...)
#         atan(x)
#
#         Return the arc tangent (measured in radians) of x.
#
#     atan2(...)
#         atan2(y, x)
#
#         Return the arc tangent (measured in radians) of y/x.
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(...)
#         atanh(x)
#
#         Return the inverse hyperbolic tangent of x.
#
#     ceil(...)
#         ceil(x)
#
# ...

# %%
def print_lyrics():
    '''This is a test function!'''
    print("I'm a lumberjack, and I'm okay.")
    print('I sleep all night and I work all day.')

# %%
type(print_lyrics)
# Out:
# function

# %%
print_lyrics
# Out:
# <function __main__.print_lyrics()>

# %%
print(print_lyrics)
# Out:
# <function print_lyrics at 0x7fa9ee45a840>

# %% [markdown]
# 注意函数名的类型和运行结果。函数通过函数名后紧跟的括号来获得*argument*，即使括号内为空，也需要由括号来表明对一个函数的调用。所以，单纯的函数名只是表示一个函数本身，只有在函数名后加了括号才表示对一个函数的调用，即得到函数的运行结果，而函数的运行结果通常是*NoneType*类型。

# %%
type(print_lyrics())
# Out:
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.
# NoneType

# %%
print_lyrics()
# Out:
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.

# %% [markdown]
# 注意函数的类型和运行结果

# %%
dir(print_lyrics)
# Out:
# ['__annotations__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
dir(print_lyrics())
# Out:
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.
# ['__bool__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
print_lyrics?
# Out:
# Signature: print_lyrics()
# Docstring: This is a test function!
# File:      ~/Github/Think_Python/<ipython-input-11-3b985aaef0e3>
# Type:      function

# %%
print_lyrics??
# Out:
# Signature: print_lyrics()
# Source:
# def print_lyrics():
#     '''This is a test function!'''
#     print("I'm a lumberjack, and I'm okay.")
#     print('I sleep all night and I work all day.')
# File:      ~/Github/Think_Python/<ipython-input-11-3b985aaef0e3>
# Type:      function

# %%
help(print_lyrics)
# Out:
# Help on function print_lyrics in module __main__:
#
# print_lyrics()
#     This is a test function!

# %%
print_lyrics()?
# Out:
#   File "<ipython-input-22-b1a6c654ed92>", line 1
#     print_lyrics()?
#                   ^
# SyntaxError: invalid syntax

# %%
print_lyrics()??
# Out:
#   File "<ipython-input-24-6f7908219ab2>", line 1
#     print_lyrics()??
#                   ^
# SyntaxError: invalid syntax

# %%
help(print_lyrics())
# Out:
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.
# Help on NoneType object:
#
# class NoneType(object)
#  |  Methods defined here:
#  |
#  |  __bool__(self, /)
#  |      self != 0
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).

# %% [markdown]
# ## Function definition and call

# %%
def print_songs():
    print('When the virgins around you')
    print('Bring tears to your eyes')
    
def repeat_songs():
    print_songs()
    print_songs()
    
repeat_songs()
# Out:
# When the virgins around you
# Bring tears to your eyes
# When the virgins around you
# Bring tears to your eyes

# %%
def repeat_songs():
    print_songs()
    print_songs()
    
def print_songs():
    print('When the virgins around you')
    print('Bring tears to your eyes')
    
repeat_songs()
# Out:
# When the virgins around you
# Bring tears to your eyes
# When the virgins around you
# Bring tears to your eyes

# %% [markdown]
# 函数的定义顺序不重要。

# %%
repeat_songs()

def repeat_songs():
    print_songs()
    print_songs()
    
def print_songs():
    print('When the virgins around you')
    print('Bring tears to your eyes')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a01611824f5f> in <module>
# ----> 1 repeat_songs()
#       2
#       3 def repeat_songs():
#       4     print_songs()
#       5     print_songs()
#
# NameError: name 'repeat_songs' is not defined

# %%
def repeat_songs():
    print_songs()
    print_songs()
    
repeat_songs()

def print_songs():
    print('When the virgins around you')
    print('Bring tears to your eyes')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-481e54e91284> in <module>
#       4     print_songs()
#       5
# ----> 6 repeat_songs()
#       7
#       8 def print_songs():
#
# <ipython-input-1-481e54e91284> in repeat_songs()
#       1
#       2 def repeat_songs():
# ----> 3     print_songs()
#       4     print_songs()
#       5
#
# NameError: name 'print_songs' is not defined

# %% [markdown]
# 但是，调用函数的时候，必须确保函数在调用前已经定义。

# %% [markdown]
# Function definition is to create function object. The statements inside the function do not run until the function is called, and the function definition generates no output.

# %% [markdown]
# ## Exercise 3_1

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
str.rjust?
# Out:
# Docstring:
# S.rjust(width[, fillchar]) -> str
#
# Return S right-justified in a string of length width. Padding is
# done using the specified fill character (default is a space).
# Type:      method_descriptor

# %%
'hello'.rjust(6, ' ')
# Out:
# ' hello'

# %%
less ex3_1_1.py
# Out:
# # Write a function named rigth_justify that takes a string as a parameter and prints the string with enough leading fillchars.
#
# def right_justify(string, num, fill):
#     print(str(string).rjust(num, '{}'.format(fill)))
#
# s = input('Please input the string: ')
# fill_char = input('Please input the fillchar: ')
# width = int(input('Please input the width: '))
#
# print(f'The width of {s} is {width} with {width - len(s)} leading {fill_char}s.')
#
# right_justify(s, width, fill_char)

# %%
run ex3_1_1.py
# Out:
# Please input the string:  hello
# Please input the fillchar:  *
# Please input the width:  10
# The width of hello is 10 with 5 leading *s.
# *****hello

# %%
less ex3_1_2.py
# Out:
# # Write a function named rigth_justify that takes every string as a parameter and prints all strings with enough leading fillchars.
#
# def right_justify(string, num, fill):
#     return str(string).rjust(num, '{}'.format(fill))
#
# container = []
# lines = int(input('The lines you want:'))
#
# for i in range(lines):
#     s = input('Please input the string: ')
#     fill_char = input('Please input the fillchar: ')
#     width = int(input('Please input the width: '))
#
#     print(f'The width of {s} is {width} with {width - len(s)} leading {fill_char}s.\n')
#
#     container.append(right_justify(s, width, fill_char))
#
# print('Now what you want to see is:')
# for i in range(lines):
#     print(container[i])

# %%
run ex3_1_2.py
# Out:
# The lines you want: 5
# Please input the string:  hello
# Please input the fillchar:
# Please input the width:  10
# The width of hello is 10 with 5 leading  s.
# Please input the string:  xiaoxiao
# Please input the fillchar:
# Please input the width:  10
# The width of xiaoxiao is 10 with 2 leading  s.
# Please input the string:
# Please input the fillchar:
# Please input the width:  10
# The width of   is 10 with 9 leading  s.
# Please input the string:  hello
# Please input the fillchar:
# Please input the width:  10
# The width of hello is 10 with 5 leading  s.
# Please input the string:  xixi
# Please input the fillchar:
# Please input the width:  10
# The width of xixi is 10 with 6 leading  s.
#
# Now what you want to see is:
#      hello
#   xiaoxiao
#
#      hello
#       xixi

# %% [markdown]
# ## Exercise 3_2

# %%
less ex3_2_1.py
# Out:
# def print_spam():
#     print('spam')
#
# def print_twice(f):
#     f()
#     f()
#
# print_twice(print_spam)

# %% [markdown]
# 如果被调用的函数本身包含参数呢？

# %%
info = input('Info:')

def print_egg(sth):
    print(sth)
    
print_egg(info)
# Out:
# Info: hello
# hello

# %%
info = input('Info:')

def print_egg(sth):
    print(sth)
    
def print_thrid(f):
    f()
    f()
    f()
    
print_thrid(print_egg)
# Out:
# Info: hello
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-c44defc430b5> in <module>
#       9     f()
#      10
# ---> 11 print_thrid(print_egg)
#
# <ipython-input-16-c44defc430b5> in print_thrid(f)
#       5
#       6 def print_thrid(f):
# ----> 7     f()
#       8     f()
#       9     f()
#
# TypeError: print_egg() missing 1 required positional argument: 'sth'

# %% [markdown]
# 由于`print_egg`函数本身是需要参数的，所以，脚本报错，提示需要*argument sth*。

# %% [markdown]
# 但是，如果对`print_egg`加入参数的话，那么`print_third`函数调用的就不是函数类型了，而是一个`NoneType`类型了。看下如下的脚本运行结果：

# %%
info = input('Info:')

def print_egg(sth):
    print(sth)
    
def print_thrid(f):
    f()
    f()
    f()
    
print_thrid(print_egg(info))
# Out:
# Info: hello
# hello
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-9c0b30278233> in <module>
#       9     f()
#      10
# ---> 11 print_thrid(print_egg(info))
#
# <ipython-input-18-9c0b30278233> in print_thrid(f)
#       5
#       6 def print_thrid(f):
# ----> 7     f()
#       8     f()
#       9     f()
#
# TypeError: 'NoneType' object is not callable

# %% [markdown]
# 既然被调用的函数`print_egg`不包含参数会出现缺少参数的报错，包含参数又会出现*NoneType*的报错，那么，这种调用包含参数的函数到底应该如何实现呢？我们尝试下如下的方式：

# %%
info = input('Info:')

def print_egg(sth):
    print(sth)
    
def print_thrid(f, arg):
    f(arg)
    f(arg)
    f(arg)
    
print_thrid(print_egg, info)
# Out:
# Info: hello
# hello
# hello
# hello

# %% [markdown]
# 但是，这是必须传递参数的情形。对于被调用函数不包含参数的情况可能又不适用了。

# %% [markdown]
# 如果脚本要同时应用于被调用函数无论有没有参数都通用的情况呢？先看下上述脚本对调用函数不包含参数的情况：

# %%
#info = input('Info:')

def print_egg():
    print('egg')
    
def print_thrid(f, arg):
    f(arg)
    f(arg)
    f(arg)
    
print_thrid(print_egg, info)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-1593c52791d5> in <module>
#       9     f(arg)
#      10
# ---> 11 print_thrid(print_egg, info)
#
# <ipython-input-21-1593c52791d5> in print_thrid(f, arg)
#       5
#       6 def print_thrid(f, arg):
# ----> 7     f(arg)
#       8     f(arg)
#       9     f(arg)
#
# TypeError: print_egg() takes 0 positional arguments but 1 was given

# %% [markdown]
# 可以看出，虽然上述脚本解决了被调用函数包含参数的情况，但是，对于被调用函数不包含参数的情况，又不适用了。

# %% [markdown]
# 所以，我们可以换个角度来考虑，即将被调用函数的参数设置为可选。

# %% [markdown]
# 首先，对于被调用函数不包含参数的情况：

# %%
#info = input('Info:')

def print_egg():
    print('egg')
    
def print_thrid(f, *arg):
    f(*arg)
    f(*arg)
    f(*arg)
    
print_thrid(print_egg)
# Out:
# egg
# egg
# egg

# %% [markdown]
# 其次，对于被调用函数强制包含参数的情况：

# %%
info = input('Info:')

def print_egg(sth = 'egg'):
    print(sth)
    
def print_thrid(f, *arg):
    f(*arg)
    f(*arg)
    f(*arg)
    
print_thrid(print_egg, info)
# Out:
# Info: hello
# hello
# hello
# hello

# %% [markdown]
# 最后，对于被调用函数不包含外部参数，采用默认值的情况：

# %%
info = input('Info:')

def print_egg(sth = 'egg'):
    print(sth)
    
def print_thrid(f, *arg):
    f(*arg)
    f(*arg)
    f(*arg)
    
print_thrid(print_egg)
# Out:
# Info: hello
# egg
# egg
# egg

# %% [markdown]
# 几点注意：

# %% [markdown]
# + 函数默认参数的表示
#
# + 函数可选参数的设置
#
# + 被调用函数包含参数的处理方式

# %%
# print a line beginning with +
def print_one():
    for i in range(2):
        print('+', end = ' ')
        for j in range(4):
            print('-', end = ' ')
    print('+')

# print a line beginning with |
def print_two():
    for i in range(2):
        print('|', end = ' ')
        for j in range(4):
            print(' ', end = ' ')
    print('|')


for i in range(2):
    print_one()
    for i in range(4):
        print_two()

print_one()
# Out:
# + - - - - + - - - - +
# |         |         |
# |         |         |
# |         |         |
# |         |         |
# + - - - - + - - - - +
# |         |         |
# |         |         |
# |         |         |
# |         |         |
# + - - - - + - - - - +

# %%
run ex3_3_1.py
# Out:
# + - - - - + - - - - +
# |         |         |
# |         |         |
# |         |         |
# |         |         |
# + - - - - + - - - - +
# |         |         |
# |         |         |
# |         |         |
# |         |         |
# + - - - - + - - - - +

# %% [markdown]
# 对上述脚本进行简化后的脚本如下：

# %%
# print a line 
def print_line(char_1, char_2):
    for i in range(2):
        print(char_1, end = ' ')
        for j in range(4):
            print(char_2, end = ' ')
    print(char_1)


for i in range(2):
    print_line('+', '-')
    for i in range(4):
        print_line('|', ' ')

print_line('+', '-')
# Out:
# + - - - - + - - - - +
# |         |         |
# |         |         |
# |         |         |
# |         |         |
# + - - - - + - - - - +
# |         |         |
# |         |         |
# |         |         |
# |         |         |
# + - - - - + - - - - +

# %%
run ex3_3_2.py
# Out:
# + - - - - + - - - - +
# |         |         |
# |         |         |
# |         |         |
# |         |         |
# + - - - - + - - - - +
# |         |         |
# |         |         |
# |         |         |
# |         |         |
# + - - - - + - - - - +

# %% [markdown]
# 考虑多行多列的情况脚本如下：

# %%
# print a line 
def print_line(char_1, char_2, num):
    for i in range(num):
        print(char_1, end = ' ')
        for j in range(4):
            print(char_2, end = ' ')
    print(char_1)


row = int(input('The row is: '))
collum = int(input('The collum is: '))

for i in range(row):
    print_line('+', '-', collum)
    for i in range(4):
        print_line('|', ' ', collum)

print_line('+', '-', collum)
# Out:
# The row is:  5
# The collum is:  3
# + - - - - + - - - - + - - - - +
# |         |         |         |
# |         |         |         |
# |         |         |         |
# |         |         |         |
# + - - - - + - - - - + - - - - +
# |         |         |         |
# |         |         |         |
# |         |         |         |
# |         |         |         |
# + - - - - + - - - - + - - - - +
# |         |         |         |
# |         |         |         |
# |         |         |         |
# |         |         |         |
# + - - - - + - - - - + - - - - +
# |         |         |         |
# |         |         |         |
# |         |         |         |
# |         |         |         |
# + - - - - + - - - - + - - - - +
# |         |         |         |
# |         |         |         |
# |         |         |         |
# |         |         |         |
# + - - - - + - - - - + - - - - +

# %%
run ex3_3_3.py
# Out:
# The row is:  20
# The collum is:  8
# + - - - - + - - - - + - - - - + - - - - + - - - - + - - - - + - - - - + - - - - +
# |         |         |         |         |         |         |         |         |
# |         |         |         |         |         |         |         |         |
# |         |         |         |         |         |         |         |         |
# |         |         |         |         |         |         |         |         |
# + - - - - + - - - - + - - - - + - - - - + - - - - + - - - - + - - - - + - - - - +
# |         |         |         |         |         |         |         |         |
# |         |         |         |         |         |         |         |         |
# |         |         |         |         |         |         |         |         |
# |         |         |         |         |         |         |         |         |
# + - - - - + - - - - + - - - - + - - - - + - - - - + - - - - + - - - - + - - - - +
# ...

# %% [markdown]
# # Chapter 4. Interface Design

# %%
import turtle

# %%
turtle
# Out:
# <module 'turtle' from '/usr/lib/python3.6/turtle.py'>

# %%
type(turtle)
# Out:
# module

# %%
dir(turtle)
# Out:
# ['Canvas',
#  'Pen',
#  'RawPen',
#  'RawTurtle',
#  'Screen',
#  'ScrolledCanvas',
#  'Shape',
#  'TK',
#  'TNavigator',
#  'TPen',
#  'Tbuffer',
#  'Terminator',
#  'Turtle',
#  'TurtleGraphicsError',
#  'TurtleScreen',
#  'TurtleScreenBase',
#  'Vec2D',
#  '_CFG',
#  '_LANGUAGE',
#  '_Root',
#  '_Screen',
#  '_TurtleImage',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__forwardmethods',
#  '__func_body',
#  '__loader__',
#  '__methodDict',
#  '__methods',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__stringBody',
#  '_alias_list',
#  '_make_global_funcs',
#  '_screen_docrevise',
#  '_tg_classes',
#  '_tg_screen_functions',
#  '_tg_turtle_functions',
#  '_tg_utilities',
#  '_turtle_docrevise',
#  '_ver',
#  'addshape',
#  'back',
#  'backward',
#  'begin_fill',
#  'begin_poly',
#  'bgcolor',
#  'bgpic',
#  'bk',
#  'bye',
#  'circle',
#  'clear',
#  'clearscreen',
#  'clearstamp',
#  'clearstamps',
#  'clone',
#  'color',
# ...

# %%
turtle?
# Out:
# Type:        module
# String form: <module 'turtle' from '/usr/lib/python3.6/turtle.py'>
# File:        /usr/lib/python3.6/turtle.py
# Docstring:
# Turtle graphics is a popular way for introducing programming to
# kids. It was part of the original Logo programming language developed
# by Wally Feurzig and Seymour Papert in 1966.
#
# Imagine a robotic turtle starting at (0, 0) in the x-y plane. After an ``import turtle``, give it
# the command turtle.forward(15), and it moves (on-screen!) 15 pixels in
# the direction it is facing, drawing a line as it moves. Give it the
# command turtle.right(25), and it rotates in-place 25 degrees clockwise.
#
# By combining together these and similar commands, intricate shapes and
# pictures can easily be drawn.
#
# ----- turtle.py
#
# This module is an extended reimplementation of turtle.py from the
# Python standard distribution up to Python 2.5. (See: http://www.python.org)
#
# It tries to keep the merits of turtle.py and to be (nearly) 100%
# ...

# %%
turtle??
# Out:
# Type:        module
# String form: <module 'turtle' from '/usr/lib/python3.6/turtle.py'>
# File:        /usr/lib/python3.6/turtle.py
# Source:
# #
# # turtle.py: a Tkinter based turtle graphics module for Python
# # Version 1.1b - 4. 5. 2009
# #
# # Copyright (C) 2006 - 2010  Gregor Lingl
# # email: glingl@aon.at
# #
# # This software is provided 'as-is', without any express or implied
# # warranty.  In no event will the authors be held liable for any damages
# # arising from the use of this software.
# #
# # Permission is granted to anyone to use this software for any purpose,
# # including commercial applications, and to alter it and redistribute it
# # freely, subject to the following restrictions:
# #
# # 1. The origin of this software must not be misrepresented; you must not
# #    claim that you wrote the original software. If you use this software
# #    in a product, an acknowledgment in the product documentation would be
# #    appreciated but is not required.
# ...

# %%
help(turtle)
# Out:
# Help on module turtle:
#
# NAME
#     turtle
#
# MODULE REFERENCE
#     https://docs.python.org/3.6/library/turtle
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     Turtle graphics is a popular way for introducing programming to
#     kids. It was part of the original Logo programming language developed
#     by Wally Feurzig and Seymour Papert in 1966.
#
#     Imagine a robotic turtle starting at (0, 0) in the x-y plane. After an ``import turtle``, give it
#     the command turtle.forward(15), and it moves (on-screen!) 15 pixels in
#     the direction it is facing, drawing a line as it moves. Give it the
#     command turtle.right(25), and it rotates in-place 25 degrees clockwise.
#
# ...

# %%
kevin = turtle.Turtle

# %%
kevin
# Out:
# turtle.Turtle

# %%
type(kevin)
# Out:
# type

# %%
dir(kevin)
# Out:
# ['DEFAULT_ANGLEOFFSET',
#  'DEFAULT_ANGLEORIENT',
#  'DEFAULT_MODE',
#  'START_ORIENTATION',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_cc',
#  '_clear',
#  '_clearstamp',
#  '_color',
#  '_colorstr',
#  '_delay',
#  '_drawturtle',
#  '_getshapepoly',
#  '_go',
#  '_goto',
#  '_newLine',
#  '_pen',
#  '_polytrafo',
#  '_reset',
#  '_rotate',
#  '_screen',
#  '_setDegreesPerAU',
#  '_setmode',
#  '_tracer',
#  '_undo',
#  '_undogoto',
#  '_update',
#  '_update_data',
#  '_write',
#  'back',
#  'backward',
#  'begin_fill',
#  'begin_poly',
#  'bk',
#  'circle',
#  'clear',
#  'clearstamp',
#  'clearstamps',
# ...

# %%
kevin?
# Out:
# Init signature: kevin(shape='classic', undobuffersize=1000, visible=True)
# Docstring:
# RawTurtle auto-creating (scrolled) canvas.
#
# When a Turtle object is created or a function derived from some
# Turtle method is called a TurtleScreen object is automatically created.
# File:           /usr/lib/python3.6/turtle.py
# Type:           type
# Subclasses:

# %%
kevin??
# Out:
# Init signature: kevin(shape='classic', undobuffersize=1000, visible=True)
# Source:
# class Turtle(RawTurtle):
#     """RawTurtle auto-creating (scrolled) canvas.
#
#     When a Turtle object is created or a function derived from some
#     Turtle method is called a TurtleScreen object is automatically created.
#     """
#     _pen = None
#     _screen = None
#
#     def __init__(self,
#                  shape=_CFG["shape"],
#                  undobuffersize=_CFG["undobuffersize"],
#                  visible=_CFG["visible"]):
#         if Turtle._screen is None:
#             Turtle._screen = Screen()
#         RawTurtle.__init__(self, Turtle._screen,
#                            shape=shape,
#                            undobuffersize=undobuffersize,
#                            visible=visible)
# File:           /usr/lib/python3.6/turtle.py
# Type:           type
# Subclasses:

# %%
import turtle

# %%
import matplotlib

# %%
# %matplotlib inline

# %%
bob = turtle.Turtle()

# %% [markdown]
# 注意，此处创建一个*Turtle*的对象，需要开启*Xming*作为*turtle*图形化显示终端，否则会报错。

# %%
bob

# %%
type(bob)
# Out:
# turtle.Turtle

# %%
dir(bob)
# Out:
# ['DEFAULT_ANGLEOFFSET',
#  'DEFAULT_ANGLEORIENT',
#  'DEFAULT_MODE',
#  'START_ORIENTATION',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_angleOffset',
#  '_angleOrient',
#  '_cc',
#  '_clear',
#  '_clearstamp',
#  '_color',
#  '_colorstr',
#  '_creatingPoly',
#  '_degreesPerAU',
#  '_delay',
#  '_drawing',
#  '_drawturtle',
#  '_fillcolor',
#  '_fillitem',
#  '_fillpath',
#  '_fullcircle',
#  '_getshapepoly',
#  '_go',
#  '_goto',
#  '_hidden_from_screen',
#  '_mode',
#  '_newLine',
#  '_orient',
#  '_outlinewidth',
#  '_pen',
#  '_pencolor',
#  '_pensize',
#  '_poly',
#  '_polytrafo',
#  '_position',
# ...

# %%
bob?
# Out:
# Type:        Turtle
# String form: <turtle.Turtle object at 0x7fc267cb2198>
# File:        /usr/lib/python3.6/turtle.py
# Docstring:
# RawTurtle auto-creating (scrolled) canvas.
#
# When a Turtle object is created or a function derived from some
# Turtle method is called a TurtleScreen object is automatically created.

# %%
bob??
# Out:
# Type:        Turtle
# String form: <turtle.Turtle object at 0x7fc267cb2198>
# File:        /usr/lib/python3.6/turtle.py
# Source:
# class Turtle(RawTurtle):
#     """RawTurtle auto-creating (scrolled) canvas.
#
#     When a Turtle object is created or a function derived from some
#     Turtle method is called a TurtleScreen object is automatically created.
#     """
#     _pen = None
#     _screen = None
#
#     def __init__(self,
#                  shape=_CFG["shape"],
#                  undobuffersize=_CFG["undobuffersize"],
#                  visible=_CFG["visible"]):
#         if Turtle._screen is None:
#             Turtle._screen = Screen()
#         RawTurtle.__init__(self, Turtle._screen,
#                            shape=shape,
#                            undobuffersize=undobuffersize,
#                            visible=visible)

# %% [markdown]
# 注意对象*kevin*和*bob*的各种基本操作的对应结果之间的差异。

# %%
turtle.mainloop?
# Out:
# Signature: turtle.mainloop()
# Docstring:
# Starts event loop - calling Tkinter's mainloop function.
#
# No argument.
#
# Must be last statement in a turtle graphics program.
# Must NOT be used if a script is run from within IDLE in -n mode
# (No subprocess) - for interactive use of turtle graphics.
#
# Example:
# >>> mainloop()
# File:      Dynamically generated function. No source code available.
# Type:      function

# %%
bob.forward?
# Out:
# Signature: bob.forward(distance)
# Docstring:
# Move the turtle forward by the specified distance.
#
# Aliases: forward | fd
#
# Argument:
# distance -- a number (integer or float)
#
# Move the turtle forward by the specified distance, in the direction
# the turtle is headed.
#
# Example (for a Turtle instance named turtle):
# >>> turtle.position()
# (0.00, 0.00)
# >>> turtle.forward(25)
# >>> turtle.position()
# (25.00,0.00)
# >>> turtle.forward(-75)
# >>> turtle.position()
# (-50.00,0.00)
# File:      /usr/lib/python3.6/turtle.py
# Type:      method

# %%
bob.clear()
bob.home()
bob.position()
# Out:
# (0.00,0.00)

# %%
bob.fd(25)
bob.lt(75)
bob.bk(100)
bob.position()
# Out:
# (-0.88,-96.59)

# %%
bob.clear()
bob.home()
bob.position()
# Out:
# (0.00,0.00)

# %%
turtle.mainloop()

# %%
kate = turtle.Turtle()

kate.fd(100)
kate.lt(90)
kate.fd(100)

turtle.mainloop()

# %%
# drawing a squaer

import turtle

square = turtle.Turtle()
square.fd(100)
square.rt(90)
square.fd(100)
square.rt(90)
square.fd(100)
square.rt(90)
square.fd(100)

# %%
turtle.mainloop()

# %% [markdown]
# 将以上程序稍作简化如下：

# %%
# drawing a square with a simpler way

import turtle

square = turtle.Turtle()

square.fd(100)
for i in range(3):
    square.rt(90)
    square.fd(100)

# %% [markdown]
# 或者更简化一点如下：

# %%
# drawing a square with the simplest way

import turtle

square = turtle.Turtle()

for i in range(4):
    square.fd(100)
    square.rt(90)

# %%
turtle.mainloop()

# %%
# write a function called square that takes a turtle parameter

import turtle

def draw_square(pen):
    for i in range(4):
        pen.fd(100)
        pen.rt(90)
       
bob = turtle.Turtle()
draw_square(bob)

# %%
# write a function called square that takes a turtle parameter and a length parameter

import turtle

def draw_square(pen, side_length):
    for i in range(4):
        pen.fd(side_length)
        pen.rt(90)
       
bob = turtle.Turtle()
length = int(input('length of square:'))
draw_square(bob, length)
# Out:
# length of square: 50

# %%
# write a function called polygon that takes a turtle parameter and a length parameter

import turtle

def draw_polygon(pen, side_length, n):
    for i in range(n):
        pen.fd(side_length)
        pen.rt(360/n)
       
bob = turtle.Turtle()
length = int(input('length of polygon:'))
sides = int(input('sides of polygon:'))
draw_polygon(bob, length, sides)
# Out:
# length of polygon: 50
# sides of polygon: 8

# %%
turtle.clearscreen()

# %% [markdown]
# 该语句用于清屏

# %%
import turtle

def draw_polygon(pen, side_length, n):
    for i in range(n):
        pen.fd(side_length)
        pen.rt(360/n)
       
length = int(input('length of polygon:'))
sides = int(input('sides of polygon:'))
times = int(input('drawing times:'))
bob = turtle.Turtle()

for i in range(times):
    draw_polygon(bob, length, sides)
    bob.rt(360/times)
# Out:
# length of polygon: 100
# sides of polygon: 3
# drawing times: 50

# %%
import turtle

def draw_polygon(pen, side_length, n):
    for i in range(n):
        pen.fd(side_length)
        pen.rt(360/n)
       
bob = turtle.Turtle()
length = int(input('length of polygon:'))
sides = int(input('sides of polygon:'))
times = int(input('drawing times:'))

for i in range(times):
    draw_polygon(bob, length, sides)
    length += 2
    bob.rt(360/times)
# Out:
# length of polygon: 100
# sides of polygon: 3
# drawing times: 50

# %% [markdown]
# 来尝试下蜗壳的画法：

# %%
import turtle

def draw_polygon(pen, side_length, n):
    for i in range(n):
        pen.fd(side_length)
        pen.rt(360/n)
       
bob = turtle.Turtle()
length = int(input('length of polygon:'))
sides = int(input('sides of polygon:'))
times = int(input('drawing times:'))

for i in range(times):
    draw_polygon(bob, length, sides)
    length += 2
    bob.rt(5)
# Out:
# length of polygon: 50
# sides of polygon: 4
# drawing times: 100

# %%
turtle.clearscreen()

# %%
# write an approximate circle

import turtle
import math

def draw_polygon(pen, side_length, n):
    for i in range(n):
        pen.fd(side_length)
        pen.rt(360/n)
       
def draw_circle(t, r):
    sides = int(input('sides of polygon:'))
    step_length = 2 * math.pi * r / sides
    draw_polygon(t, step_length, sides)
    
bob = turtle.Turtle()
radius = int(input('radius of circle:'))
draw_circle(bob, radius)
# Out:
# radius of circle: 20
# sides of polygon: 500

# %%
# write an approximate circle

import turtle
import math

def draw_polygon(pen, side_length, n):
    for i in range(n):
        pen.fd(side_length)
        pen.rt(360/n)
       
def draw_circle(t, r):
    sides = int(input('sides of polygon:'))
    step_length = 2 * math.pi * r / sides
    draw_polygon(t, step_length, sides)
    
bob = turtle.Turtle()
radius = int(input('radius of circle:'))
draw_circle(bob, radius)
# Out:
# radius of circle: 100
# sides of polygon: 100

# %%
turtle.clearscreen()

# %%
# write several approximate circles

import turtle
import math

def draw_polygon(pen, side_length, n):
    for i in range(n):
        pen.fd(side_length)
        pen.rt(360/n)
       
def draw_circle(t, r):
    sides = 30 
    step_length = 2 * math.pi * r / sides
    draw_polygon(t, step_length, sides)
    
bob = turtle.Turtle()
radius = int(input('radius of circle:'))

for i in range(10):
    draw_circle(bob, radius)
    radius -= 2
# Out:
# radius of circle: 50

# %%
# write several approximate circles

import turtle
import math

def draw_polygon(pen, side_length, n):
    for i in range(n):
        pen.fd(side_length)
        pen.rt(360/n)
       
def draw_circle(t, r):
    sides = 30 
    step_length = 2 * math.pi * r / sides
    draw_polygon(t, step_length, sides)
    
bob = turtle.Turtle()
radius = int(input('radius of circle:'))

for i in range(5):
    draw_circle(bob, radius)
    radius -= 10 
    bob.rt(90)
    bob.fd(10)
    bob.lt(90)
# Out:
# radius of circle: 100

# %%
# write an arc

import turtle
import math

def draw_polygon(pen, side_length, n, d):
    for i in range(n):
        pen.fd(side_length)
        pen.rt(d/n)
       
def draw_arc(t, r, degree):
    sides = int(input('sides of polygon:'))
    step_length = 2 * math.pi * r / sides
    draw_polygon(t, step_length, sides, degree)
    
bob = turtle.Turtle()
radius = int(input('radius of circle:'))
arc = int(input('degree of arc:'))
draw_arc(bob, radius, arc)

# %% [markdown]
# ## Exercise 4_2

# %%
import turtle
pen = turtle.Turtle()

# %%
pen.circle?
# Out:
# Signature: pen.circle(radius, extent=None, steps=None)
# Docstring:
# Draw a circle with given radius.
#
# Arguments:
# radius -- a number
# extent (optional) -- a number
# steps (optional) -- an integer
#
# Draw a circle with given radius. The center is radius units left
# of the turtle; extent - an angle - determines which part of the
# circle is drawn. If extent is not given, draw the entire circle.
# If extent is not a full circle, one endpoint of the arc is the
# current pen position. Draw the arc in counterclockwise direction
# if radius is positive, otherwise in clockwise direction. Finally
# the direction of the turtle is changed by the amount of extent.
#
# As the circle is approximated by an inscribed regular polygon,
# steps determines the number of steps to use. If not given,
# it will be calculated automatically. Maybe used to draw regular
# polygons.
#
# call: circle(radius)                  # full circle
# --or: circle(radius, extent)          # arc
# ...

# %%
turtle.clearscreen()
turtle.home()

# %% [markdown]
# 首先，看下一个花瓣的画法：

# %%
import turtle
pen = turtle.Turtle()

pen.circle(100, 60)
pen.lt(120)
pen.circle(100, 60)

# %% [markdown]
# 由此，可以定义一个花瓣函数：

# %%
def pedal():
    pen.circle(100, 60)
    pen.lt(120)
    pen.circle(100, 60)

# %% [markdown]
# 尝试改变花瓣的形状，对弧的半径和弧度进行调整后函数如下：

# %%
import turtle

pen = turtle.Turtle()
def pedal(r, d):
    pen.circle(r, d)
    pen.lt(180 - d)
    pen.circle(r, d)
    
radius = int(input('r:'))
degree = int(input('d:'))
pedal(radius, degree)
# Out:
# r: 150
# d: 70

# %% [markdown]
# 接下来，考虑多个花瓣的情况：

# %%
turtle.clearscreen()
turtle.home()

# %% [markdown]
# 注意，由于画完每片花瓣之后的鼠标，到下一片花瓣开始的鼠标之间的角度不好计算，但是，花瓣之间的角度取决于花瓣片数，所以，干脆让鼠标在每次画完一个花瓣之后就回到最初的起点，然后下一次花瓣的鼠标起点就可以通过花瓣数量的增长，计算出鼠标角度的偏移量。

# %%
import turtle

pen = turtle.Turtle()

def pedal(r, d):
    '''单个花瓣的绘制函数，注意反向线条的角度处理'''
    pen.circle(r, d)
    pen.lt(180 - d)
    pen.circle(r, d)
    
radius = int(input('r:'))
degree = int(input('d:'))
num = int(input('petals:'))

for i in range(num):
    '''每画完一个花瓣，就让鼠标回到原始状态，绘制下个花瓣就只要考虑采用花瓣序号对起始角度进行偏置就行了'''
    pedal(radius, degree)
    pen.home()
    pen.rt((i + 1) * 360 / num)
# Out:
# r: 400
# d: 20
# petals: 20

# %% [markdown]
# 如果要对花瓣着色该怎么办呢？通过`dir(turtle)`命令可以查到有关颜色或填充的*method*包括*color*、*fillcolor*、*filling*和*pencolor*。下面分别来看下：

# %%
pen.color?
# Out:
# Signature: pen.color(*args)
# Docstring:
# Return or set the pencolor and fillcolor.
#
# Arguments:
# Several input formats are allowed.
# They use 0, 1, 2, or 3 arguments as follows:
#
# color()
#     Return the current pencolor and the current fillcolor
#     as a pair of color specification strings as are returned
#     by pencolor and fillcolor.
# color(colorstring), color((r,g,b)), color(r,g,b)
#     inputs as in pencolor, set both, fillcolor and pencolor,
#     to the given value.
# color(colorstring1, colorstring2),
# color((r1,g1,b1), (r2,g2,b2))
#     equivalent to pencolor(colorstring1) and fillcolor(colorstring2)
#     and analogously, if the other input format is used.
#
# If turtleshape is a polygon, outline and interior of that polygon
# is drawn with the newly set colors.
# For mor info see: pencolor, fillcolor
#
# Example (for a Turtle instance named turtle):
# >>> turtle.color('red', 'green')
# >>> turtle.color()
# ('red', 'green')
# >>> colormode(255)
# ...

# %%
pen.color()
# Out:
# ('black', 'black')

# %%
pen.fillcolor?
# Out:
# Signature: pen.fillcolor(*args)
# Docstring:
# Return or set the fillcolor.
#
# Arguments:
# Four input formats are allowed:
#   - fillcolor()
#     Return the current fillcolor as color specification string,
#     possibly in hex-number format (see example).
#     May be used as input to another color/pencolor/fillcolor call.
#   - fillcolor(colorstring)
#     s is a Tk color specification string, such as "red" or "yellow"
#   - fillcolor((r, g, b))
#     *a tuple* of r, g, and b, which represent, an RGB color,
#     and each of r, g, and b are in the range 0..colormode,
#     where colormode is either 1.0 or 255
#   - fillcolor(r, g, b)
#     r, g, and b represent an RGB color, and each of r, g, and b
#     are in the range 0..colormode
#
# If turtleshape is a polygon, the interior of that polygon is drawn
# with the newly set fillcolor.
#
# Example (for a Turtle instance named turtle):
# >>> turtle.fillcolor('violet')
# >>> col = turtle.pencolor()
# >>> turtle.fillcolor(col)
# ...

# %%
pen.fillcolor()
# Out:
# 'black'

# %%
pen.pencolor?
# Out:
# Signature: pen.pencolor(*args)
# Docstring:
# Return or set the pencolor.
#
# Arguments:
# Four input formats are allowed:
#   - pencolor()
#     Return the current pencolor as color specification string,
#     possibly in hex-number format (see example).
#     May be used as input to another color/pencolor/fillcolor call.
#   - pencolor(colorstring)
#     s is a Tk color specification string, such as "red" or "yellow"
#   - pencolor((r, g, b))
#     *a tuple* of r, g, and b, which represent, an RGB color,
#     and each of r, g, and b are in the range 0..colormode,
#     where colormode is either 1.0 or 255
#   - pencolor(r, g, b)
#     r, g, and b represent an RGB color, and each of r, g, and b
#     are in the range 0..colormode
#
# If turtleshape is a polygon, the outline of that polygon is drawn
# with the newly set pencolor.
#
# Example (for a Turtle instance named turtle):
# >>> turtle.pencolor('brown')
# >>> tup = (0.2, 0.8, 0.55)
# >>> turtle.pencolor(tup)
# ...

# %%
pen.pencolor()
# Out:
# 'black'

# %%
pen.filling?
# Out:
# Signature: pen.filling()
# Docstring:
# Return fillstate (True if filling, False else).
#
# No argument.
#
# Example (for a Turtle instance named turtle):
# >>> turtle.begin_fill()
# >>> if turtle.filling():
# ...     turtle.pensize(5)
# ... else:
# ...     turtle.pensize(3)
# File:      /usr/lib/python3.6/turtle.py
# Type:      method

# %%
pen.filling()
# Out:
# False

# %%
turtle.clearscreen()
turtle.home()

# %%
import turtle

pen = turtle.Turtle()
pen.color('red', 'yellow')

def pedal(r, d):
    '''单个花瓣的绘制函数，注意反向线条的角度处理'''
    pen.circle(r, d)
    pen.lt(180 - d)
    pen.circle(r, d)
    
radius = int(input('r:'))
degree = int(input('d:'))
num = int(input('petals:'))

for i in range(num):
    '''每画完一个花瓣，就让鼠标回到原始状态，绘制下个花瓣就只要考虑采用花瓣序号对起始角度进行偏置就行了'''
    pedal(radius, degree)
    pen.home()
    pen.rt((i + 1) * 360 / num)
# Out:
# r: 100
# d: 60
# petals: 10

# %% [markdown]
# 执行后会发现，虽然设置了画笔颜色和填充颜色，但是只有花瓣边缘被着了色，但内部并没有填充颜色。

# %% [markdown]
# 再次查阅对象的*method*，发现有*begin_fill*和*end_fill*两个方法。

# %%
pen.end_fill?
# Out:
# Signature: pen.end_fill()
# Docstring:
# Fill the shape drawn after the call begin_fill().
#
# No argument.
#
# Example (for a Turtle instance named turtle):
# >>> turtle.color("black", "red")
# >>> turtle.begin_fill()
# >>> turtle.circle(60)
# >>> turtle.end_fill()
# File:      /usr/lib/python3.6/turtle.py
# Type:      method

# %%
turtle.clearscreen()
turtle.home()

# %%
import turtle

pen = turtle.Turtle()
pen.color('red', 'yellow')
pen.begin_fill()

def pedal(r, d):
    '''单个花瓣的绘制函数，注意反向线条的角度处理'''
    pen.circle(r, d)
    pen.lt(180 - d)
    pen.circle(r, d)
    
radius = int(input('r:'))
degree = int(input('d:'))
num = int(input('petals:'))

for i in range(num):
    '''每画完一个花瓣，就让鼠标回到原始状态，绘制下个花瓣就只要考虑采用花瓣序号对起始角度进行偏置就行了'''
    pedal(radius, degree)
    pen.home()
    pen.rt((i + 1) * 360 / num)
    
pen.end_fill()
# Out:
# r: 150
# d: 60
# petals: 7

# %% [markdown]
# 关于画板擦除

# %%
turtle.clearscreen()
turtle.home()

# %% [markdown]
# 使用上述两条命令可以将画板擦除干净，复原到初始状态。

# %% [markdown]
# ## Exercise 4_3

# %%
import turtle
from math import cos, pi

pen = turtle.Turtle()
radius = int(input('radius:'))
sides = int(input('sides:'))
angle = (180 - 360.0 / sides) / 2

def side_length(r, d):
    value = abs(r * cos(d / 180.0 * pi))
    return round(value)
    
def triangle(r, d):
    pen.fd(r)
    pen.lt(180 - d)
    pen.fd(side_length(r, d))
    pen.lt(180 - d)
    pen.fd(r)
    
for i in range(sides):
    triangle(radius, angle)
    pen.home()
    pen.rt(angle * (i + 1))
# Out:
# radius: 100
# sides: 6

# %%
side_length(100, 6)
# Out:
# 99

# %%
100 * cos(pi / 3)
# Out:
# 50.000000000000014

# %%
import math

# %%
math.cos?
# Out:
# Docstring:
# cos(x)
#
# Return the cosine of x (measured in radians).
# Type:      builtin_function_or_method
